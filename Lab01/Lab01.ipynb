# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread("hinh.jpg",cv2.IMREAD_REDUCED_COLOR_2)
cv2_imshow(img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=270x270 at 0x7FCDAB38AB50>

# %% [markdown]
# **EX2**

# %%
path =r'hinh.jpg'
image =cv2.imread(path,0)
window_name = 'image'

# %%
cv2_imshow(image)
cv2.waitKey(0) 

cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=539x540 at 0x7FCDAB32D950>

# %% [markdown]
# **EX3**

# %%
import os

# %%
image_path = r'hinh.jpg'
directory = r'/content'

# %%
img = cv2.imread(image_path)

# %%
os.chdir(directory)

# %%
print("Before saving image:")  
print(os.listdir(directory))
# Out:
# Before saving image:
# ['.config', '.ipynb_checkpoints', 'hinh.jpg', '59d46jua8lq71.jpg', 'sample_data']

# %%
filename = 'savedImage.jpg'

# %%
cv2.imwrite(filename, img)
# Out:
# True

# %%
print("After saving image:")  
print(os.listdir(directory))
  
print('Successfully saved')
# Out:
# After saving image:
# ['.config', '.ipynb_checkpoints', 'hinh.jpg', 'savedImage.jpg', '59d46jua8lq71.jpg', 'sample_data']
# Successfully saved

# %% [markdown]
# **EX4**

# %%
image = cv2.imread('hinh.jpg')
B, G, R = cv2.split(image)

# %%
cv2_imshow( image)
cv2.waitKey(0)
  
cv2_imshow( B)
cv2.waitKey(0)
  
cv2_imshow( G)
cv2.waitKey(0)
  
cv2_imshow( R)
cv2.waitKey(0)
  
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=539x540 at 0x7FCDAB2C7710>
# <PIL.Image.Image image mode=L size=539x540 at 0x7FCDAB2C7710>
# <PIL.Image.Image image mode=L size=539x540 at 0x7FCDAB2C7710>
# <PIL.Image.Image image mode=L size=539x540 at 0x7FCDAB396290>

# %% [markdown]
# **EX5**

# %%
import numpy as np

# %%
image1 = cv2.imread('hinh.jpg') 
image2 = cv2.imread('duck.jpg')

# %%
sub = cv2.subtract(image1, image2)

# %%
cv2.imshow('Subtracted Image', sub)

# %%
if cv2.waitKey(0) & 0xff == 27: 
    cv2.destroyAllWindows()

# %% [markdown]
# **EX6**

# %%
img1 = cv2.imread('1bit1.png') 
img2 = cv2.imread('2bit2.png')

# %%
dest_and = cv2.bitwise_and(img2, img1, mask = None)

# %%
cv2_imshow( dest_and)
# Out:
# <PIL.Image.Image image mode=RGB size=499x250 at 0x7F7FC3C6F190>

# %%
if cv2.waitKey(0) & 0xff == 27:
    cv2.destroyAllWindows()

# %%
dest_or = cv2.bitwise_or(img2, img1, mask = None)

# %%
cv2_imshow( dest_or)
# Out:
# <PIL.Image.Image image mode=RGB size=499x250 at 0x7F7FC3C6F290>

# %%
dest_xor = cv2.bitwise_xor(img1, img2, mask = None)
cv2_imshow( dest_xor)
# Out:
# <PIL.Image.Image image mode=RGB size=499x250 at 0x7F7FC42F3590>

# %%
dest_not1 = cv2.bitwise_not(img1, mask = None)
dest_not2 = cv2.bitwise_not(img2, mask = None)
cv2_imshow( dest_not1)
cv2_imshow( dest_not2)
# Out:
# <PIL.Image.Image image mode=RGB size=499x250 at 0x7F7FC4B54FD0>
# <PIL.Image.Image image mode=RGB size=499x250 at 0x7F7FC42E5610>

# %% [markdown]
# **EX7**

# %%
import matplotlib.pyplot as plt

# %%
image = cv2.imread("hinh.jpg", 1)

# %%
half = cv2.resize(image, (0, 0), fx = 0.1, fy = 0.1)
bigger = cv2.resize(image, (1050, 1610))
 
stretch_near = cv2.resize(image, (780, 540),
               interpolation = cv2.INTER_NEAREST)

# %%
Titles =["Original", "Half", "Bigger", "Interpolation Nearest"]
images =[image, half, bigger, stretch_near]
count = 4

# %%
for i in range(count):
    plt.subplot(2, 2, i + 1)
    plt.title(Titles[i])
    plt.imshow(images[i])
 
plt.show()

# %% [markdown]
# **EX8**

# %%
path = r'hinh.jpg'

# %%
image = cv2.imread(path)

# %%
window_name = 'Image'

# %%
image = cv2.copyMakeBorder(image, 10, 10, 10, 10, cv2.BORDER_CONSTANT, None, value = 0)

# %%
cv2_imshow( image)
# Out:
# <PIL.Image.Image image mode=RGB size=559x560 at 0x7FCDAA491D50>

# %%
image = cv2.copyMakeBorder(image, 100, 100, 50, 50, cv2.BORDER_REFLECT)
 
# Displaying the image
cv2_imshow( image)
# Out:
# <PIL.Image.Image image mode=RGB size=659x760 at 0x7FCDAA482210>

# %% [markdown]
# **EX9**

# %%
path = r'hinh.jpg'
src = cv2.imread(path)
window_name = 'Image'

# %%
image = cv2.cvtColor(src, cv2.COLOR_BGR2GRAY )

# %%
cv2_imshow( image)
# Out:
# <PIL.Image.Image image mode=L size=539x540 at 0x7FCDAA491690>

# %%
image = cv2.cvtColor(src, cv2.COLOR_BGR2HSV )
cv2_imshow( image)
# Out:
# <PIL.Image.Image image mode=RGB size=539x540 at 0x7FCDAA47DC10>

# %% [markdown]
# **EX10**

# %%
path = r'hinh.jpg'

# %%
image = cv2.imread(path)
window_name = 'Image'
start_point = (0, 0)
end_point = (250, 250)
color = (0, 255, 0)
thickness = 1000
image = cv2.line(image, start_point, end_point, color, thickness)
cv2_imshow( image)
# Out:
# <PIL.Image.Image image mode=RGB size=539x540 at 0x7FCDAA49AC50>

# %% [markdown]
# **EX11**

# %%
image = cv2.imread(path)
start_point = (0, 0) 
end_point = (200, 200) 
color = (0, 255, 0) 
thickness = 9
image = cv2.arrowedLine(image, start_point, end_point,
                                     color, thickness) 
  

cv2_imshow( image)
# Out:
# <PIL.Image.Image image mode=RGB size=539x540 at 0x7FCDAB2BF2D0>

# %% [markdown]
# **EX12**

# %%
image = cv2.imread(path)
window_name = 'Image'
   
center_coordinates = (120, 100)
  
axesLength = (1000, 250)
  
angle = 0
  
startAngle = 0
  
endAngle = 360

color = (0, 0, 255)

thickness = 5

image = cv2.ellipse(image, center_coordinates, axesLength,
           angle, startAngle, endAngle, color, thickness)

cv2_imshow( image)
# Out:
# <PIL.Image.Image image mode=RGB size=539x540 at 0x7FCDAA4A21D0>

# %% [markdown]
# **EX14**

# %%
import cv2
import matplotlib.pyplot as plt
  
# reads image as RGB
img = cv2.imread('logo2.png')
  
# shows the image
plt.imshow(img)
plt.imshow(img, cmap ='nipy_spectral')

# %%
import cv2
  
# Reads the image
img = cv2.imread('logo2.png')
  
# Convert to YCrCb color space
img = cv2.cvtColor(img, cv2.COLOR_BGR2YCrCb)
  
# Shows the image
plt.imshow( img) 
  
cv2.waitKey(0)         
cv2.destroyAllWindows()

# %% [markdown]
# **EX15**

# %%
laplacian = cv2.Laplacian(img, cv2.CV_64F)
plt.imshow( laplacian)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# **EX16**

# %%
import cv2
    

path = r'logo2.png'
    

image = cv2.imread(path)
    

window_name = 'Image'
  

font = cv2.FONT_HERSHEY_SIMPLEX
  

org = (50, 50)
  

fontScale = 1
   

color = (255, 0, 0)
  

thickness = 2
   

image = cv2.putText(image, 'university', org, font, 
                   fontScale, color, thickness, cv2.LINE_AA)
   

plt.imshow( image)

# %% [markdown]
# **EX17**

# %%
import cv2 
   

path = r'logo2.png'
   

image = cv2.imread(path)

window_name = 'Image'
  

start_point = (5, 5)
  

end_point = (220, 220)
  

color = (255, 0, 0)
  

thickness = 2

image = cv2.rectangle(image, start_point, end_point, color, thickness)
  

plt.imshow( image)

# %% [markdown]
# **EX18**

# %%
import cv2 
    

path = r'logo2.png'

image = cv2.imread(path, 0)


start_point = (100, 50)
   

end_point = (125, 80)

color = (0, 0, 0)

thickness = -1

image = cv2.rectangle(image, start_point, end_point, color, thickness)

plt.imshow( image)

# %% [markdown]
# **EX19**

# %%
import cv2
   

path = r'logo2.png'
   

image = cv2.imread(path)
   

window_name = 'Image'
  

center_coordinates = (120, 50)

radius = 20
  

color = (255, 0, 0)
  

thickness = 2
  

image = cv2.circle(image, center_coordinates, radius, color, thickness)

plt.imshow( image)

# %% [markdown]
# **Ex20**

# %%
import cv2

import os
  

image_path = r'logo2.png'
  

directory = r'/content'
  

img = cv2.imread(image_path)
  

os.chdir(directory)
  

print("Before saving image:")  
print(os.listdir(directory))  

filename = 'savedImage.jpg'
  

cv2.imwrite(filename, img)
  

print("After saving image:")  
print(os.listdir(directory))
  
print('Successfully saved')
# Out:
# Before saving image:
# ['.config', 'logo2.png', 'sample_data']
# After saving image:
# ['.config', 'logo2.png', 'savedImage.jpg', 'sample_data']
# Successfully saved
